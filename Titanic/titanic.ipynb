# %%
import pandas as pd

train = pd.read_csv("dataset/train.csv")
test = pd.read_csv("dataset/test.csv")

# %%
train.head(5)
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.shape
# Out:
# (891, 12)

# %%
test.shape
# Out:
# (418, 11)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Age, Cabin, Embarked

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %% [markdown]
# # Age, Fare, Cabin

# %%
test.head(5)
# Out:
#    PassengerId  Pclass                                          Name     Sex
# 0          892       3                              Kelly, Mr. James    male  \
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
def bar_chart(feature):
    survived = train[train['Survived'] == 1][feature].value_counts()
    dead = train[train['Survived'] == 0][feature].value_counts()
    
    df = pd.DataFrame([survived, dead])
    df.index = ['Survived', 'Dead']
    
    df.plot(kind='bar')

# %%
bar_chart('Sex')

# %%
bar_chart('Pclass')

# %%
bar_chart('SibSp')

# %%
bar_chart('Parch')

# %%
bar_chart('Embarked')

# %%
f, ax = plt.subplots(1,2,figsize=(18,8))
train['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot(x='Survived',data=train,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
# Ordinal
pd.crosstab(train.Pclass, train.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_a946f_row0_col0, #T_a946f_row1_col1, #T_a946f_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_a946f_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_a946f_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_a946f_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_a946f_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_a946f_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_a946f_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_a946f_row3_col0, #T_a946f_row3_col1, #T_a946f_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a946f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_a946f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a946f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_a946f_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a946f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a946f_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_a946f_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_a946f_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_a946f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a946f_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_a946f_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_a946f_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_a946f_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_a946f_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_a946f_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_a946f_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_a946f_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_a946f_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_a946f_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_a946f_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Ordinal
pd.crosstab([train.Sex, train.Survived],train.Pclass, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_72e3b_row0_col0, #T_72e3b_row0_col1, #T_72e3b_row0_col3, #T_72e3b_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_72e3b_row0_col2, #T_72e3b_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_72e3b_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_72e3b_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_72e3b_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_72e3b_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_72e3b_row2_col1, #T_72e3b_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_72e3b_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_72e3b_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_72e3b_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_72e3b_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_72e3b_row4_col0, #T_72e3b_row4_col1, #T_72e3b_row4_col2, #T_72e3b_row4_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_72e3b">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_72e3b_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_72e3b_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_72e3b_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_72e3b_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72e3b_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#       <th id="T_72e3b_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_72e3b_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_72e3b_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_72e3b_row0_col2" class="data row0 col2" >72</td>
#       <td id="T_72e3b_row0_col3" class="data row0 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_72e3b_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_72e3b_row1_col0" class="data row1 col0" >91</td>
#       <td id="T_72e3b_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_72e3b_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_72e3b_row1_col3" class="data row1 col3" >233</td>
#     </tr>
#     <tr>
#       <th id="T_72e3b_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#       <th id="T_72e3b_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_72e3b_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_72e3b_row2_col1" class="data row2 col1" >91</td>
#       <td id="T_72e3b_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_72e3b_row2_col3" class="data row2 col3" >468</td>
#     </tr>
#     <tr>
#       <th id="T_72e3b_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_72e3b_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_72e3b_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_72e3b_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_72e3b_row3_col3" class="data row3 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_72e3b_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_72e3b_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_72e3b_row4_col0" class="data row4 col0" >216</td>
#       <td id="T_72e3b_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_72e3b_row4_col2" class="data row4 col2" >491</td>
#       <td id="T_72e3b_row4_col3" class="data row4 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
f,ax=plt.subplots(1, 2, figsize=(18,8))
train['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'], ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot(x='Pclass',hue='Survived',data=train, ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
sns.catplot(x='Pclass', y='Survived', hue='Sex', data=train, kind='bar')
plt.show()

# %%
print(f"Oldest: {train['Age'].max()} \nYoungest: {train['Age'].min()} \nAverage: {train['Age'].mean()}")
# Out:
# Oldest: 80.0
# Youngest: 0.42
# Average: 29.69911764705882

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
sns.violinplot(x="Pclass", y="Age", hue="Survived", split=True, data=train, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10))


sns.violinplot(x="Sex", y="Age", hue="Survived", split=True, data=train, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))

plt.show()

# %% [markdown]
# # Feature Engineering

# %%
train_test = [train, test]

for d in train_test:
    d['Title'] = d['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
train['Title'].value_counts()
# Out:
# Title
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Major         2
# Col           2
# Countess      1
# Capt          1
# Ms            1
# Sir           1
# Lady          1
# Mme           1
# Don           1
# Jonkheer      1
# Name: count, dtype: int64

# %%
# Mapping
title_mapping = {"Mr": 0, "Miss": 1, "Mrs": 2, 
                 "Master": 3, "Dr": 3, "Rev": 3, "Col": 3, "Major": 3, "Mlle": 3,"Countess": 3,
                 "Ms": 3, "Lady": 3, "Jonkheer": 3, "Don": 3, "Dona" : 3, "Mme": 3,"Capt": 3,"Sir": 3 }
for d in train_test:
    d['Title'] = d['Title'].map(title_mapping)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S      0
# 1      0          PC 17599  71.2833   C85        C      2
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1
# 3      0            113803  53.1000  C123        S      2
# 4      0            373450   8.0500   NaN        S      0

# %%
bar_chart('Title')

# %%
bar_chart('Title')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch
# 0            1         0       3    male  22.0      1      0  \
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Title
# 0         A/5 21171   7.2500   NaN        S      0
# 1          PC 17599  71.2833   C85        C      2
# 2  STON/O2. 3101282   7.9250   NaN        S      1
# 3            113803  53.1000  C123        S      2
# 4            373450   8.0500   NaN        S      0

# %% [markdown]
# # Missing values

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Title            0
# dtype: int64

# %%
grouping = train.groupby("Title")["Age"]

train['Age'].fillna(grouping.transform("mean"), inplace=True)
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch
# 0            1         0       3    male  22.0      1      0  \
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Title
# 0         A/5 21171   7.2500   NaN        S      0
# 1          PC 17599  71.2833   C85        C      2
# 2  STON/O2. 3101282   7.9250   NaN        S      1
# 3            113803  53.1000  C123        S      2
# 4            373450   8.0500   NaN        S      0

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Title            0
# dtype: int64

# %%
facet = sns.FacetGrid(train, hue="Survived", aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %%
facet = sns.FacetGrid(train, hue="Survived", aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(0, 20)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %%
for dataset in train_test:
    dataset.loc[dataset['Age'] <= 16, 'Age'] = 5
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 26), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 26) & (dataset['Age'] <= 36), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 36) & (dataset['Age'] <= 62), 'Age'] = 3
    dataset.loc[dataset['Age'] > 62, 'Age'] = 4

# Display the modified datasets
print(train.head())
print(test.head())
# Out:
#    PassengerId  Survived  Pclass     Sex  Age  SibSp  Parch            Ticket
# 0            1         0       3    male  1.0      1      0         A/5 21171  \
# 1            2         1       1  female  3.0      1      0          PC 17599
# 2            3         1       3  female  1.0      0      0  STON/O2. 3101282
# 3            4         1       1  female  2.0      1      0            113803
# 4            5         0       3    male  2.0      0      0            373450
#
#       Fare Cabin Embarked  Title
# 0   7.2500   NaN        S      0
# 1  71.2833   C85        C      2
# 2   7.9250   NaN        S      1
# 3  53.1000  C123        S      2
# 4   8.0500   NaN        S      0
#    PassengerId  Pclass                                          Name     Sex
# 0          892       3                              Kelly, Mr. James    male  \
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#    Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Title
# 0  2.0      0      0   330911   7.8292   NaN        Q      0
# 1  3.0      1      0   363272   7.0000   NaN        S      2
# 2  3.0      0      0   240276   9.6875   NaN        Q      0
# 3  2.0      0      0   315154   8.6625   NaN        S      0
# 4  1.0      1      1  3101298  12.2875   NaN        S      2

# %%
bar_chart('Age')

# %%
p1 = train[train['Pclass'] == 1]['Embarked'].value_counts()
p2 = train[train['Pclass'] == 2]['Embarked'].value_counts()
p3 = train[train['Pclass'] == 3]['Embarked'].value_counts()

classes = pd.DataFrame([p1, p2, p3])
classes.index = ['1', '2', '3']
classes.head()
# Out:
# Embarked    S   C   Q
# 1         127  85   2
# 2         164  17   3
# 3         353  66  72

# %%
classes.plot(kind='bar')
# Out:
# <Axes: >

# %%
for d in train_test:
    d['Embarked'] = d['Embarked'].fillna('S')

# %%
train.Embarked.isnull().sum()
# Out:
# 0

# %%
embarked_mapping = {"S": 0, "C": 1, "Q": 2}

for d in train_test:
    d['Embarked'] = d['Embarked'].map(embarked_mapping)

train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex  Age  SibSp  Parch            Ticket
# 0            1         0       3    male  1.0      1      0         A/5 21171  \
# 1            2         1       1  female  3.0      1      0          PC 17599
# 2            3         1       3  female  1.0      0      0  STON/O2. 3101282
# 3            4         1       1  female  2.0      1      0            113803
# 4            5         0       3    male  2.0      0      0            373450
#
#       Fare Cabin  Embarked  Title
# 0   7.2500   NaN         0      0
# 1  71.2833   C85         1      2
# 2   7.9250   NaN         0      1
# 3  53.1000  C123         0      2
# 4   8.0500   NaN         0      0

# %%
train.Cabin.value_counts()
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
for d in train_test:
    d['Cabin'] = d['Cabin'].str[:1]
    
p1 = train[train['Pclass'] == 1]['Cabin'].value_counts()
p2 = train[train['Pclass'] == 2]['Cabin'].value_counts()
p3 = train[train['Pclass'] == 3]['Cabin'].value_counts()

cabins = pd.DataFrame([p1, p2, p3])
cabins.index = ['1', '2', '3']
cabins.head()
# Out:
# Cabin     C     B     D     E     A    T    F    G
# 1      59.0  47.0  29.0  25.0  15.0  1.0  NaN  NaN
# 2       NaN   NaN   4.0   4.0   NaN  NaN  8.0  NaN
# 3       NaN   NaN   NaN   3.0   NaN  NaN  5.0  4.0

# %%
cabins.plot(kind='bar')
# Out:
# <Axes: >

# %%
cabin_mapping = {"A": 0, "B": 0.5, "C": 1.0, "D": 1.5, "E": 2.0, "F": 2.5, "G": 3.0}

for d in train_test:
    d['Cabin'] = d['Cabin'].map(cabin_mapping)
grouping_class = train.groupby("Pclass")["Cabin"]

train['Cabin'].fillna(grouping_class.transform("median"), inplace=True)

train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# Title          0
# dtype: int64

# %%
train["Family Size"] = train.SibSp + train.Parch + 1

facet = sns.FacetGrid(train, hue="Survived", aspect=4)
facet.map(sns.kdeplot, 'Family Size' ,shade= True)
facet.set(xlim=(0, train['Family Size'].max()))
facet.add_legend()

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %%
train['Family Size']
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 886    1
# 887    1
# 888    4
# 889    1
# 890    1
# Name: Family Size, Length: 891, dtype: int64

# %%
family_mapping = {1: 0, 2: 0.4, 3: 0.8, 4: 1.2, 5: 1.6, 6: 2, 7: 2.4, 8: 2.8, 9: 3.2, 10: 3.6, 11: 4}

train['Family Size'] = train['Family Size'].map(family_mapping)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex  Age  SibSp  Parch            Ticket
# 0            1         0       3    male  1.0      1      0         A/5 21171  \
# 1            2         1       1  female  3.0      1      0          PC 17599
# 2            3         1       3  female  1.0      0      0  STON/O2. 3101282
# 3            4         1       1  female  2.0      1      0            113803
# 4            5         0       3    male  2.0      0      0            373450
#
#       Fare  Cabin  Embarked  Title  Family Size
# 0   7.2500    2.5         0      0          0.4
# 1  71.2833    1.0         1      2          0.4
# 2   7.9250    2.5         0      1          0.0
# 3  53.1000    1.0         0      2          0.4
# 4   8.0500    2.5         0      0          0.0

# %%
train.drop(['PassengerId', 'Ticket', 'SibSp', 'Parch'], axis=1, inplace=True)
train.shape
# Out:
# (891, 9)

# %%
train.head()
# Out:
#    Survived  Pclass     Sex  Age     Fare  Cabin  Embarked  Title  Family Size
# 0         0       3    male  1.0   7.2500    2.5         0      0          0.4
# 1         1       1  female  3.0  71.2833    1.0         1      2          0.4
# 2         1       3  female  1.0   7.9250    2.5         0      1          0.0
# 3         1       1  female  2.0  53.1000    1.0         0      2          0.4
# 4         0       3    male  2.0   8.0500    2.5         0      0          0.0

# %%
target = train.Survived
train.drop('Survived', axis = 1, inplace=True)

# %%
sex_mapping = {"male": 0, "female": 1}

train['Sex'] = train['Sex'].map(sex_mapping)

# %% [markdown]
# # Machine Learning

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Pclass       891 non-null    int64
#  1   Sex          891 non-null    int64
#  2   Age          891 non-null    float64
#  3   Fare         891 non-null    float64
#  4   Cabin        891 non-null    float64
#  5   Embarked     891 non-null    int64
#  6   Title        891 non-null    int64
#  7   Family Size  891 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 55.8 KB

# %%
from sklearn.model_selection import KFold
from sklearn. model_selection import cross_val_score

k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
# Decision Tree
clf_dt = DecisionTreeClassifier()
score = cross_val_score(clf_dt, train, target, cv=k_fold, scoring='accuracy')
score
# Out:
# array([0.76666667, 0.82022472, 0.80898876, 0.76404494, 0.76404494,
#        0.7752809 , 0.78651685, 0.78651685, 0.7752809 , 0.78651685])

# %%
np.mean(score)*100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 np.mean(score)*100
#
# NameError: name 'np' is not defined
